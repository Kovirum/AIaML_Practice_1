# %%
# Вывод всех доступных магических команд
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %%timeit

# Измерение времени выполнения кода
# %time sum(range(1000000))
# Out:
# CPU times: total: 15.6 ms
# Wall time: 39.2 ms
# CPU times: total: 46.9 ms
# Wall time: 36.4 ms
# CPU times: total: 31.2 ms
# Wall time: 34.3 ms
# CPU times: total: 31.2 ms
# Wall time: 34.1 ms
# CPU times: total: 31.2 ms
# Wall time: 33.6 ms
# CPU times: total: 46.9 ms
# Wall time: 33.7 ms
# CPU times: total: 31.2 ms
# Wall time: 34.1 ms
# CPU times: total: 31.2 ms
# Wall time: 33.7 ms
# CPU times: total: 31.2 ms
# Wall time: 33.7 ms
# CPU times: total: 31.2 ms
# Wall time: 34 ms
# CPU times: total: 46.9 ms
# Wall time: 35.8 ms
# CPU times: total: 31.2 ms
# Wall time: 34 ms
# CPU times: total: 31.2 ms
# Wall time: 34.7 ms
# CPU times: total: 46.9 ms
# Wall time: 35.5 ms
# CPU times: total: 31.2 ms
# Wall time: 45.7 ms
# CPU times: total: 31.2 ms
# Wall time: 35 ms
# CPU times: total: 31.2 ms
# Wall time: 33.1 ms
# CPU times: total: 31.2 ms
# Wall time: 33.6 ms
# CPU times: total: 46.9 ms
# Wall time: 33.1 ms
# CPU times: total: 31.2 ms
# Wall time: 32.9 ms
# ...

# %%
# Запись кода в файл
# %%writefile task3_testcript.py
for i in range(10):
    print(f"Итерация {i}")

# Выполнение скрипта
# !python task3_testscript.py
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %%
# Список файлов текущей директории
# %ls
# Out:
#  Том в устройстве C имеет метку Windows 10
#  Серийный номер тома: 7686-91E1
#
#  Содержимое папки C:\Users\user\Desktop\Учёба\СКФУ\2 курс\2 семестр\ИИиМО\Отчёты\Лабораторная 1\AIaML_Practice_1\notebooks\main_tasks
#
# 26.02.2026  14:37    <DIR>          .
# 26.02.2026  14:37    <DIR>          ..
# 26.02.2026  14:18    <DIR>          .ipynb_checkpoints
# 26.02.2026  14:17             1 735 task1.ipynb
# 26.02.2026  14:00             3 849 task2.ipynb
# 26.02.2026  13:59               114 task2_example.txt
# 26.02.2026  14:37            15 292 task3.ipynb
#                4 файлов         20 990 байт
#                3 папок  123 698 798 592 байт свободно

# %%
# Просмотр истории команд
# %history
# Out:
# %time
#
# # Измерение времени выполнения кода
# for i in range(10**1000):
#     i = i ** 2
# %%timeit
#
# # Измерение времени выполнения кода
# %time sum(range(100000000))
# %%timeit
#
# # Измерение времени выполнения кода
# %time sum(range(1000000))
# # Список файлов текущей директории
# %ls
# # Список файлов текущей директории
# %ls
# # Просмотр истории команд
# %history
