# %%
# !cd
# !mkdir test_folder
# Out:
# C:\Users\user\Desktop\Учёба\СКФУ\2 курс\2 семестр\ИИиМО\Отчёты\Лабораторная 1\AIaML_Practice_1\notebooks\main_tasks

# %%
# !rmdir test_folder

# %% [markdown]
# !help
