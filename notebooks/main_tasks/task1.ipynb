# %% [markdown]
# # Практическое задание №1
#
# **Жирный** и *курсивный* текст
#
# 1. Это
# 2. Нумерованный
# 3. Список
#
# - А
# - это
# - Маркированный
# - список
#
# $$det(A−λI)=0$$

# %%
name = input("Введите имя: ")
print(f"Привет, {name}! Добро пожаловать в Jupyter Notebook!")
# Out:
# Введите имя:  Никита
# Привет, Никита! Добро пожаловать в Jupyter Notebook!
