# %%
2 + 2
# Out:
# 4

# %%
a = 10
b = 15
print(a + b)
# Out:
# 25

# %%
n = 7

# %%
for i in range(n):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# Какой-то **комментарий**
# # Важный
